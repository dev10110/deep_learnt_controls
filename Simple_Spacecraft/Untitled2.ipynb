# %%
from rocket import Rocket

import numpy as np
import matplotlib.pyplot as plt

# %%
r = Rocket()

# %%
r
# Out:
# Rocket
# Initial State: (146.31206863707604, 1688.845997350289, 3.5836346719973218, -20.35188150137033, 9808.124075904594)

# %%
r.lunar_guidance_live()

# %%
len(r.t)
# Out:
# 2476

# %%
len(r.u1_mag)
# Out:
# 2476

# %%
plt.plot(r.x, r.z)
ax = plt.gca()
ax.set_aspect('equal', 'datalim')
plt.grid()

# %%
plt.plot(r.t, r.vz)

# %%
plt.plot(r.vx, r.vz)

# %%
plt.plot(r.t, r.u1_mag)

# %%
plt.plot(r.t, r.u2_angle)

# %%
plt.plot(r.t, r.m)

# %%
 r.m[-1]/r.m[0]
# Out:
# 0.8707778027097434
